# %% [markdown]
# # Introduction
#
# This IPython notebook illustrates how to use multiple blockers and combine the results.
#
# First, we need to import *py_entitymatching* package and other libraries as follows:

# %%
# Import py_entitymatching package
import py_entitymatching as em
import os
import pandas as pd

# %% [markdown]
# Then, read the (sample) input tables for blocking purposes.

# %%
# Get the datasets directory
datasets_dir = em.get_install_path() + os.sep + 'datasets'

# Get the paths of the input tables
path_A = datasets_dir + os.sep + 'person_table_A.csv'
path_B = datasets_dir + os.sep + 'person_table_B.csv'

# %%
# Read the CSV files and set 'ID' as the key attribute
A = em.read_csv_metadata(path_A, key='ID')
B = em.read_csv_metadata(path_B, key='ID')

# %%
# # Read the CSV files and set 'ID' as the key attribute
# A = em.read_csv_metadata('../../Data for Assignments/citeseer.csv',low_memory=False) # setting the parameter low_memory to False  to speed up loading.
# B = em.read_csv_metadata('../../Data for Assignments/dblp.csv', low_memory=False)

# %%
# # Set 'id' as the keys to the input tables
# em.set_key(A, 'id')
# em.set_key(B, 'id')

# %% [markdown]
# # Combining Multiple Blockers

# %%
#Blocking plan :

#A, B --overlap blocking--> candset --attr-equiv-block--> candset  |
#                                                                  | 
#A, B ------------rule-based-blocking--------------------> candset |----union--->candset
#                                                                  |
#A, B -----------black-box-blocking----------------------> candset |

# %%
A
# Out:
#    ID              name  birth_year  hourly_wage  \
# 0  a1       Kevin Smith        1989         30.0
# 1  a2  Michael Franklin        1988         27.5
# 2  a3    William Bridge        1986         32.0
# 3  a4      Binto George        1987         32.5
# 4  a5   Alphonse Kemper        1984         35.0
#
#                            address  zipcode
# 0       607 From St, San Francisco    94107
# 1  1652 Stockton St, San Francisco    94122
# 2   3131 Webster St, San Francisco    94107
# 3     423 Powell St, San Francisco    94122
# 4  1702 Post Street, San Francisco    94122

# %%
B
# Out:
#    ID            name  birth_year  hourly_wage  \
# 0  b1     Mark Levene        1987         29.5
# 1  b2     Bill Bridge        1986         32.0
# 2  b3   Mike Franklin        1988         27.5
# 3  b4     Joseph Kuan        1982         26.0
# 4  b5   Alfons Kemper        1984         35.0
# 5  b6  Michael Brodie        1987         32.5
#
#                               address  zipcode
# 0       108 Clement St, San Francisco    94107
# 1      3131 Webster St, San Francisco    94107
# 2     1652 Stockton St, San Francisco    94122
# 3       108 South Park, San Francisco    94122
# 4  170 Post St, Apt 4,  San Francisco    94122
# 5   133 Clement Street, San Francisco    94107

# %%
len(A)*len(B)
# Out:
# 30

# %%
# Overlap blocking over input tables
ob = em.OverlapBlocker()
# block using name
C = ob.block_tables(A, B, 'name', 'name', word_level=True, overlap_size=1, 
                    l_output_attrs=['name', 'birth_year'], 
                    r_output_attrs=['name', 'birth_year'],
                    show_progress=False)
C
# Out:
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_stringsimjoin\utils\converter.py:99: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if col_type == pd.np.object:
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l_df[l_dummy_overlap_attr] = l_df[l_overlap_attr]
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df[r_dummy_overlap_attr] = r_df[r_overlap_attr]
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:615: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table[overlap_attr] = values
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_stringsimjoin\utils\validation.py:30: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if attr_type != pd.np.object:
#    _id ltable_ID rtable_ID       ltable_name  ltable_birth_year  \
# 0    0        a3        b2    William Bridge               1986
# 1    1        a2        b3  Michael Franklin               1988
# 2    2        a5        b5   Alphonse Kemper               1984
# 3    3        a2        b6  Michael Franklin               1988
#
#       rtable_name  rtable_birth_year
# 0     Bill Bridge               1986
# 1   Mike Franklin               1988
# 2   Alfons Kemper               1984
# 3  Michael Brodie               1987

# %%
# Overlap blocking over input tables
ob = em.OverlapBlocker()
# block using name
C = ob.block_tables(A, B, 'name', 'name', word_level=True, overlap_size=1, 
                    l_output_attrs=['name', 'birth_year'], 
                    r_output_attrs=['name', 'birth_year'],
                    show_progress=False)
C
# Out:
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_stringsimjoin\utils\converter.py:99: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if col_type == pd.np.object:
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l_df[l_dummy_overlap_attr] = l_df[l_overlap_attr]
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df[r_dummy_overlap_attr] = r_df[r_overlap_attr]
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\blocker\overlap_blocker.py:615: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table[overlap_attr] = values
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_stringsimjoin\utils\validation.py:30: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if attr_type != pd.np.object:
#    _id ltable_ID rtable_ID       ltable_name  ltable_birth_year  \
# 0    0        a3        b2    William Bridge               1986
# 1    1        a2        b3  Michael Franklin               1988
# 2    2        a5        b5   Alphonse Kemper               1984
# 3    3        a2        b6  Michael Franklin               1988
#
#       rtable_name  rtable_birth_year
# 0     Bill Bridge               1986
# 1   Mike Franklin               1988
# 2   Alfons Kemper               1984
# 3  Michael Brodie               1987

# %%
len(C)
# Out:
# 4

# %%
# Attribute equivalence blocking: block C using birth_year
ab = em.AttrEquivalenceBlocker()
D = ab.block_candset(C, 'birth_year', 'birth_year', show_progress=False)

# %%
D
# Out:
#    _id ltable_ID rtable_ID       ltable_name  ltable_birth_year  \
# 0    0        a3        b2    William Bridge               1986
# 1    1        a2        b3  Michael Franklin               1988
# 2    2        a5        b5   Alphonse Kemper               1984
#
#      rtable_name  rtable_birth_year
# 0    Bill Bridge               1986
# 1  Mike Franklin               1988
# 2  Alfons Kemper               1984

# %%
len(D)
# Out:
# 3

# %%
# Rule-based blocking over input tables
# first get features that can be used
feature_table = em.get_features_for_blocking(A, B, validate_inferred_attr_types=False)
# Out:
# c:\users\rmartinez4\anaconda3\envs\py37\lib\site-packages\py_entitymatching\feature\attributeutils.py:191: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if returned_type == bool or returned_type == pd.np.bool_:

# %%
feature_table
# Out:
#                         feature_name left_attribute right_attribute  \
# 0                     ID_ID_lev_dist             ID              ID
# 1                      ID_ID_lev_sim             ID              ID
# 2                          ID_ID_jar             ID              ID
# 3                          ID_ID_jwn             ID              ID
# 4                          ID_ID_exm             ID              ID
# 5              ID_ID_jac_qgm_3_qgm_3             ID              ID
# 6          name_name_jac_qgm_3_qgm_3           name            name
# 7      name_name_cos_dlm_dc0_dlm_dc0           name            name
# 8      name_name_jac_dlm_dc0_dlm_dc0           name            name
# 9                      name_name_mel           name            name
# 10                name_name_lev_dist           name            name
# 11                 name_name_lev_sim           name            name
# 12                     name_name_nmw           name            name
# 13                      name_name_sw           name            name
# 14         birth_year_birth_year_exm     birth_year      birth_year
# 15         birth_year_birth_year_anm     birth_year      birth_year
# 16    birth_year_birth_year_lev_dist     birth_year      birth_year
# 17     birth_year_birth_year_lev_sim     birth_year      birth_year
# 18       hourly_wage_hourly_wage_exm    hourly_wage     hourly_wage
# 19       hourly_wage_hourly_wage_anm    hourly_wage     hourly_wage
# 20  hourly_wage_hourly_wage_lev_dist    hourly_wage     hourly_wage
# 21   hourly_wage_hourly_wage_lev_sim    hourly_wage     hourly_wage
# 22               zipcode_zipcode_exm        zipcode         zipcode
# 23               zipcode_zipcode_anm        zipcode         zipcode
# 24          zipcode_zipcode_lev_dist        zipcode         zipcode
# 25           zipcode_zipcode_lev_sim        zipcode         zipcode
#
#    left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 0                 None                 None          lev_dist
# 1                 None                 None           lev_sim
# 2                 None                 None              jaro
# 3                 None                 None      jaro_winkler
# 4                 None                 None       exact_match
# 5                qgm_3                qgm_3           jaccard
# 6                qgm_3                qgm_3           jaccard
# 7              dlm_dc0              dlm_dc0            cosine
# 8              dlm_dc0              dlm_dc0           jaccard
# 9                 None                 None       monge_elkan
# 10                None                 None          lev_dist
# 11                None                 None           lev_sim
# 12                None                 None  needleman_wunsch
# 13                None                 None    smith_waterman
# 14                None                 None       exact_match
# 15                None                 None          abs_norm
# 16                None                 None          lev_dist
# 17                None                 None           lev_sim
# 18                None                 None       exact_match
# 19                None                 None          abs_norm
# 20                None                 None          lev_dist
# 21                None                 None           lev_sim
# 22                None                 None       exact_match
# 23                None                 None          abs_norm
# 24                None                 None          lev_dist
# 25                None                 None           lev_sim
#
#                                                              function  \
# 0                     <function ID_ID_lev_dist at 0x000001D27FC840D8>
# 1                      <function ID_ID_lev_sim at 0x000001D27FCC4798>
# 2                          <function ID_ID_jar at 0x000001D27FCC4318>
# 3                          <function ID_ID_jwn at 0x000001D27FCC41F8>
# 4                          <function ID_ID_exm at 0x000001D27FCC4828>
# 5              <function ID_ID_jac_qgm_3_qgm_3 at 0x000001D27FCC49D8>
# 6          <function name_name_jac_qgm_3_qgm_3 at 0x000001D27FCC4AF8>
# 7      <function name_name_cos_dlm_dc0_dlm_dc0 at 0x000001D27FCC4C18>
# 8      <function name_name_jac_dlm_dc0_dlm_dc0 at 0x000001D27FCC4D38>
# 9                      <function name_name_mel at 0x000001D27FCC4E58>
# 10                <function name_name_lev_dist at 0x000001D27FCC4F78>
# 11                 <function name_name_lev_sim at 0x000001D27FCE90D8>
# 12                     <function name_name_nmw at 0x000001D27FCE91F8>
# 13                      <function name_name_sw at 0x000001D27FCE9318>
# 14         <function birth_year_birth_year_exm at 0x000001D27FCE9438>
# 15         <function birth_year_birth_year_anm at 0x000001D27FCE9558>
# 16    <function birth_year_birth_year_lev_dist at 0x000001D27FCE9678>
# 17     <function birth_year_birth_year_lev_sim at 0x000001D27FCE9798>
# 18       <function hourly_wage_hourly_wage_exm at 0x000001D27FCE98B8>
# 19       <function hourly_wage_hourly_wage_anm at 0x000001D27FCE99D8>
# 20  <function hourly_wage_hourly_wage_lev_dist at 0x000001D27FCE9AF8>
# 21   <function hourly_wage_hourly_wage_lev_sim at 0x000001D27FCE9C18>
# 22               <function zipcode_zipcode_exm at 0x000001D27FCE9D38>
# 23               <function zipcode_zipcode_anm at 0x000001D27FCE9E58>
# 24          <function zipcode_zipcode_lev_dist at 0x000001D27FCE9F78>
# 25           <function zipcode_zipcode_lev_sim at 0x000001D27FCEE0D8>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#     is_auto_generated
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True
# 10               True
# 11               True
# 12               True
# 13               True
# 14               True
# 15               True
# 16               True
# 17               True
# 18               True
# 19               True
# 20               True
# 21               True
# 22               True
# 23               True
# 24               True
# 25               True

# %%
# Create rule-based blocker
rb = em.RuleBasedBlocker()
# Add rule : block tuples if name_name_lev(ltuple, rtuple) < 0.4
rb.add_rule(['name_name_lev_sim(ltuple, rtuple) < 0.4'], feature_table)
# Out:
# '_rule_0'

# %%
E = rb.block_tables(A, B, l_output_attrs=['name'], r_output_attrs=['name'], show_progress=False)

# %%
E
# Out:
#    _id ltable_ID rtable_ID       ltable_name     rtable_name
# 0    0        a2        b3  Michael Franklin   Mike Franklin
# 1    1        a2        b6  Michael Franklin  Michael Brodie
# 2    2        a3        b2    William Bridge     Bill Bridge
# 3    3        a3        b6    William Bridge  Michael Brodie
# 4    4        a4        b2      Binto George     Bill Bridge
# 5    5        a5        b5   Alphonse Kemper   Alfons Kemper

# %%
len(E)
# Out:
# 6

# %%
# Apply black box blocker
# Create black box blocker
bb = em.BlackBoxBlocker()

# %%
# define a black box function. 
# The blocker function should drop tuple pairs whose last name do not match
# The function has to do the following steps
#  1) Get name attributes from each of the tuples
#  2) Split name attribute to get last name
#  3) if last names donot match return True

# %%
def my_function(x, y):
    # x, y will be of type pandas series
    
    # get name attribute
    x_name = x['name']
    y_name = y['name']
    # get last names
    x_name = x_name.split(' ')[1]
    y_name = y_name.split(' ')[1]
    # check if last names match
    if x_name != y_name:
        return True
    else:
        return False

# %%
bb.set_black_box_function(my_function)

# %%
F = bb.block_tables(A, B, l_output_attrs=['name'], r_output_attrs=['name'], show_progress=False)

# %%
F
# Out:
#    _id ltable_ID rtable_ID       ltable_name    rtable_name
# 0    0        a2        b3  Michael Franklin  Mike Franklin
# 1    1        a3        b2    William Bridge    Bill Bridge
# 2    2        a5        b5   Alphonse Kemper  Alfons Kemper

# %%
len(F)
# Out:
# 3

# %%
# Combine all the blocker outputs
G = em.combine_blocker_outputs_via_union([D, E, F])

# %%
G
# Out:
#    _id ltable_ID rtable_ID       ltable_name  ltable_birth_year  \
# 0    0        a2        b3  Michael Franklin               1988
# 1    1        a2        b6  Michael Franklin               1988
# 2    2        a3        b2    William Bridge               1986
# 3    3        a3        b6    William Bridge               1986
# 4    4        a4        b2      Binto George               1987
# 5    5        a5        b5   Alphonse Kemper               1984
#
#       rtable_name  rtable_birth_year
# 0   Mike Franklin               1988
# 1  Michael Brodie               1987
# 2     Bill Bridge               1986
# 3  Michael Brodie               1987
# 4     Bill Bridge               1986
# 5   Alfons Kemper               1984

# %%
len(G)
# Out:
# 6

# %%
em.show_properties(G)
# Out:
# id: 2003599313736
# key: _id
# fk_ltable: ltable_ID
# fk_rtable: rtable_ID
# ltable(obj.id): 2003400570312
# rtable(obj.id): 2003598121096
